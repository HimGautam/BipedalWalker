# %%
import multiprocessing
import os
import pickle
import neat
import gym
import numpy as np

# %%
runs_per_net = 2

# Use the NN network phenotype and the discrete actuator force function.
def eval_genome(genome, config):
    net = neat.nn.FeedForwardNetwork.create(genome, config)
#     net = neat.nn.recurrent.RecurrentNetwork.create(genome, config)

    fitnesses = []

    for runs in range(runs_per_net):
        env = gym.make("BipedalWalker-v3")
        observation = env.reset()[0:14]
        
        fitness = 0.0
        done = False
        while not done:

            action = net.activate(observation)
            observation, reward, done, info = env.step(action)
            observation = observation[0:14]
            fitness += reward

        fitnesses.append(fitness)
    return np.mean(fitnesses)


def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        genome.fitness = eval_genome(genome, config)


def run():
    #put config-feedforward nn file in the same directory as this file
    local_dir = os.path.dirname("__file__")
    config_path = os.path.join(local_dir, 'config-feedforward nn')
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_path)

    pop = neat.Population(config)
    stats = neat.StatisticsReporter()
    pop.add_reporter(stats)
    pop.add_reporter(neat.StdOutReporter(True))

    pe = neat.ParallelEvaluator(multiprocessing.cpu_count(), eval_genome)
    winner = pop.run(pe.evaluate)

    # Save the winner.
    with open('winner-feedforward nn', 'wb') as f:
        pickle.dump(winner, f)

    print(winner)

# %%
#for training the agent
run()
# Out:
# /home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
#  ****** Running generation 0 ******
#
# Population's average fitness: -126.32824 stdev: 21.85606
# Best fitness: -67.22796 - size: (7, 55) - species 2 - id 83
# Average adjusted fitness: 0.512
# Mean genetic distance 2.786, standard deviation 0.359
# Population of 219 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    33   -100.2    0.568     0
#      2    0    52    -67.2    0.558     0
#      3    0    34   -102.1    0.504     0
#      4    0    16   -111.6    0.583     0
#      5    0    60   -104.5    0.497     0
#      6    0    20   -104.9    0.484     0
#      7    0     4   -108.6    0.386     0
# Total extinctions: 0
# Generation time: 22.406 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -120.55320 stdev: 22.00045
# Best fitness: -67.10939 - size: (7, 55) - species 2 - id 83
# Average adjusted fitness: 0.626
# Mean genetic distance 2.734, standard deviation 0.434
# Population of 218 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    26    -99.5    0.700     0
#      2    1     9    -67.1    0.612     0
#      3    1     5    -94.1    0.663     0
#      4    1    25   -109.6    0.640     0
#      5    1    18   -100.9    0.675     0
#      6    1     5   -104.4    0.610     0
#      7    1   127   -107.8    0.482     0
#      8    0     3       --       --     0
# Total extinctions: 0
# Generation time: 20.385 sec (21.395 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -117.10766 stdev: 19.98265
# Best fitness: -67.09135 - size: (7, 55) - species 2 - id 83
# Average adjusted fitness: 0.517
# Mean genetic distance 2.740, standard deviation 0.592
# Population of 221 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    58   -101.6    0.622     1
#      2    2    25    -67.1    0.567     0
#      3    2    17   -105.0    0.427     1
#      4    2    31   -105.0    0.530     0
#      5    2    30    -97.9    0.624     0
#      6    2    14   -114.6    0.381     1
#      7    2    31    -96.8    0.580     0
#      8    1    15   -102.5    0.403     0
# Total extinctions: 0
# Generation time: 19.300 sec (20.697 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -119.28669 stdev: 21.47684
# Best fitness: -67.12200 - size: (7, 55) - species 2 - id 83
# Average adjusted fitness: 0.540
# Mean genetic distance 2.778, standard deviation 0.588
# Population of 219 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    44    -99.7    0.572     2
#      2    3    26    -67.1    0.532     1
#      3    3    20   -101.7    0.567     2
#      4    3    26   -102.6    0.489     0
#      5    3    21    -99.2    0.578     1
#      6    3    23   -109.3    0.523     2
#      7    3    25    -96.0    0.597     0
#      8    2    31   -102.1    0.459     0
#      9    0     3       --       --     0
# Total extinctions: 0
# Generation time: 21.597 sec (20.922 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -116.85404 stdev: 19.55976
# Best fitness: -95.99608 - size: (8, 53) - species 7 - id 765
# Average adjusted fitness: 0.760
# Mean genetic distance 2.796, standard deviation 0.557
# Population of 220 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    28    -97.4    0.802     0
#      2    4    11   -101.9    0.649     2
#      3    4    23   -103.3    0.697     3
#      4    4    21   -100.7    0.658     0
#      5    4    23    -98.3    0.833     2
#      6    4    26   -109.3    0.724     3
#      7    4    25    -96.0    0.851     1
#      8    3     4    -97.0    0.789     0
#      9    1    21   -105.6    0.840     0
#     10    0    38       --       --     0
# Total extinctions: 0
# Generation time: 18.548 sec (20.447 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -114.55586 stdev: 18.98591
# Best fitness: -58.34272 - size: (7, 55) - species 6 - id 1054
# Average adjusted fitness: 0.629
# Mean genetic distance 2.808, standard deviation 0.547
# Population of 220 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    21    -99.5    0.648     1
#      2    5     8   -107.6    0.532     3
#      3    5    22    -99.6    0.619     4
#      4    5    22    -99.4    0.638     0
#      5    5    22    -97.5    0.628     0
#      6    5    16    -58.3    0.621     0
#      7    5    15    -99.3    0.655     2
#      8    4    28    -99.7    0.605     1
#      9    2    10   -101.9    0.660     0
#     10    1    56    -94.7    0.687     0
# Total extinctions: 0
# Generation time: 15.151 sec (19.564 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -111.84353 stdev: 17.46730
# Best fitness: -50.45476 - size: (7, 55) - species 6 - id 1054
# Average adjusted fitness: 0.506
# Mean genetic distance 2.785, standard deviation 0.532
# Population of 218 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    22    -99.7    0.543     2
#      2    6    16    -92.6    0.463     4
#      3    6    20    -98.9    0.436     5
#      4    6    22    -99.7    0.505     1
#      5    6    22    -98.8    0.498     1
#      6    6    19    -50.5    0.443     0
#      7    6    19    -99.5    0.545     3
#      8    5    20    -99.7    0.536     2
#      9    3    16   -100.6    0.518     0
#     10    2    42    -91.3    0.577     0
# Total extinctions: 0
# Generation time: 14.574 sec (18.851 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -113.80064 stdev: 19.80939
# Best fitness: -54.67544 - size: (7, 55) - species 6 - id 1054
# Average adjusted fitness: 0.534
# Mean genetic distance 2.725, standard deviation 0.548
# Population of 219 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    23    -99.5    0.560     3
#      2    7    12    -94.1    0.545     5
#      3    7    19   -100.7    0.466     6
#      4    7    21    -99.9    0.490     2
#      5    7    21    -85.5    0.527     0
#      6    7    20    -54.7    0.479     1
#      7    7    21    -99.2    0.559     4
#      8    6    29    -99.7    0.565     3
#      9    4    20   -100.6    0.564     0
#     10    3    33    -92.0    0.584     1
# Total extinctions: 0
# Generation time: 17.208 sec (18.646 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -111.79027 stdev: 18.97235
# Best fitness: -59.01791 - size: (7, 55) - species 6 - id 1054
# Average adjusted fitness: 0.586
# Mean genetic distance 2.748, standard deviation 0.594
# Population of 220 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    24    -99.5    0.642     4
#      2    8     4    -96.3    0.593     6
#      3    8    25    -98.8    0.521     7
#      4    8    20    -95.4    0.507     0
#      5    8    20   -100.0    0.532     1
#      6    8    21    -59.0    0.606     2
#      7    8    22    -99.1    0.629     5
#      8    7    34    -99.4    0.595     4
#      9    5    21    -94.1    0.593     0
#     10    4    29    -91.9    0.646     2
# Total extinctions: 0
# Generation time: 14.102 sec (18.141 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -110.72653 stdev: 20.13310
# Best fitness: -46.88589 - size: (7, 55) - species 6 - id 1054
# Average adjusted fitness: 0.580
# Mean genetic distance 2.725, standard deviation 0.591
# Population of 222 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    24    -99.5    0.571     5
#      2    9    20   -102.6    0.588     7
#      3    9    22    -99.0    0.481     8
#      4    9    21    -95.5    0.562     1
#      5    9    21    -99.8    0.579     2
#      6    9    22    -46.9    0.560     0
#      7    9    23    -99.2    0.588     6
#      8    8    18    -94.3    0.538     0
#      9    6    24    -93.5    0.655     0
#     10    5    27    -91.8    0.677     3
# Total extinctions: 0
# Generation time: 13.839 sec (17.711 average)
#
#  ****** Running generation 10 ******
# Population's average fitness: -111.45051 stdev: 22.00051
# Best fitness: -60.77297 - size: (7, 55) - species 6 - id 1054
# Average adjusted fitness: 0.599
# Mean genetic distance 2.663, standard deviation 0.596
# Population of 216 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    23    -99.3    0.616     6
#      2   10     2    -94.0    0.516     8
#      3   10    21    -99.0    0.538     9
#      4   10    21    -92.1    0.567     0
#      5   10    20    -97.3    0.564     3
#      6   10    20    -60.8    0.597     1
#      7   10    22    -99.2    0.608     7
#      8    9    36   -101.5    0.551     1
#      9    7    25    -93.4    0.728     0
#     10    6    26    -91.8    0.710     4
# Total extinctions: 0
# Generation time: 17.275 sec (17.198 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -108.68724 stdev: 17.66567
# Best fitness: -64.89966 - size: (7, 55) - species 6 - id 1054
# Average adjusted fitness: 0.622
# Mean genetic distance 2.663, standard deviation 0.587
# Population of 218 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    22    -99.5    0.630     7
#      2   11    14   -103.4    0.664     9
#      3   11    20    -96.8    0.552    10
#      4   11    13    -91.9    0.611     0
#      5   11    24    -97.7    0.573     4
#      6   11    26    -64.9    0.533     2
#      7   11    21    -99.2    0.600     8
#      8   10    27    -94.9    0.604     2
#      9    8    24    -92.3    0.702     0
#     10    7    27    -91.8    0.750     5
# Total extinctions: 0
# Generation time: 13.158 sec (16.475 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -109.31750 stdev: 18.31370
# Best fitness: -64.25717 - size: (7, 55) - species 6 - id 1054
# Average adjusted fitness: 0.619
# Mean genetic distance 2.673, standard deviation 0.586
# Population of 219 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    24    -99.4    0.620     8
#      2   12    15   -100.5    0.525    10
#      3   12    21    -96.4    0.607    11
#      4   12    17    -98.0    0.562     1
#      5   12    25    -98.2    0.574     5
#      6   12    18    -64.3    0.610     3
#      7   12    22    -99.2    0.662     9
#      8   11    26    -92.8    0.571     0
#      9    9    25    -73.4    0.716     0
#     10    8    26    -91.8    0.743     6
# Total extinctions: 0
# Generation time: 12.871 sec (15.832 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -108.48118 stdev: 21.84259
# Best fitness: -31.68881 - size: (7, 38) - species 9 - id 2788
# Average adjusted fitness: 0.509
# Mean genetic distance 2.722, standard deviation 0.556
# Population of 221 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    23    -98.3    0.515     9
#      2   13    16    -91.8    0.451    11
#      3   13    20    -96.4    0.452    12
#      4   13    20    -90.4    0.489     0
#      5   13    24    -93.9    0.511     6
#      6   13    18    -57.3    0.436     4
#      7   13    23    -99.4    0.542    10
#      8   12    24    -92.6    0.465     0
#      9   10    26    -31.7    0.612     0
#     10    9    27    -91.8    0.615     7
# Total extinctions: 0
# Generation time: 15.558 sec (15.228 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -105.12204 stdev: 18.74318
# Best fitness: -30.32252 - size: (8, 38) - species 9 - id 3011
# Average adjusted fitness: 0.509
# Mean genetic distance 2.740, standard deviation 0.525
# Population of 218 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    22    -98.2    0.530    10
#      2   14    33    -94.6    0.478    12
#      3   14    19    -96.9    0.429    13
#      4   14    19    -93.2    0.414     1
#      5   14    23    -93.2    0.535     7
#      6   14    20    -63.0    0.442     5
#      7   14    22    -99.4    0.521    11
#      8   13     6    -75.5    0.537     0
#      9   11    27    -30.3    0.610     0
#     10   10    27    -91.8    0.591     8
# Total extinctions: 0
# Generation time: 11.461 sec (14.520 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -104.68879 stdev: 20.35882
# Best fitness: -14.71318 - size: (8, 38) - species 9 - id 3211
# Average adjusted fitness: 0.471
# Mean genetic distance 2.703, standard deviation 0.534
# Population of 220 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15     4    -98.4    0.470    11
#      2   15    17    -74.7    0.472    13
#      3   15    20    -95.3    0.442    14
#      4   15    20    -76.4    0.433     0
#      5   15    24    -78.9    0.504     0
#      6   15    19    -60.8    0.406     6
#      7   15    23    -99.4    0.475    12
#      8   14    41    -93.9    0.425     1
#      9   12    26    -14.7    0.546     0
#     10   11    26    -91.8    0.540     9
# Total extinctions: 0
# Generation time: 14.364 sec (14.441 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -103.36789 stdev: 27.59294
# Best fitness: -17.26682 - size: (8, 38) - species 9 - id 3211
# Average adjusted fitness: 0.458
# Mean genetic distance 2.656, standard deviation 0.572
# Population of 220 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16     9   -100.0    0.371    12
#      2   16    20    -98.5    0.479    14
#      3   16    19    -96.7    0.361    15
#      4   16    19    -97.5    0.411     1
#      5   16    25    -59.4    0.509     0
#      6   16    18    -66.9    0.384     7
#      7   16    21    -98.6    0.418    13
#      8   15    37    -18.5    0.576     0
#      9   13    27    -17.3    0.560     1
#     10   12    25    -91.8    0.508    10
# Total extinctions: 0
# Generation time: 19.391 sec (14.923 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -101.64575 stdev: 25.05607
# Best fitness: -14.88041 - size: (8, 38) - species 9 - id 3211
# Average adjusted fitness: 0.474
# Mean genetic distance 2.726, standard deviation 0.597
# Population of 221 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    14   -100.1    0.421    13
#      2   17    18    -98.7    0.443    15
#      3   17    18    -96.5    0.368    16
#      4   17    20    -92.1    0.440     2
#      5   17    24    -60.7    0.525     1
#      6   17    19    -54.0    0.430     8
#      7   17    20    -98.8    0.439    14
#      8   16    34    -16.6    0.542     0
#      9   14    28    -14.9    0.584     2
#     10   13    26    -91.8    0.543    11
# Total extinctions: 0
# Generation time: 19.148 sec (15.117 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -98.15898 stdev: 28.96963
# Best fitness: 54.12404 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.345
# Mean genetic distance 2.755, standard deviation 0.589
# Population of 221 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    17    -99.6    0.318    14
#      2   18    42    -98.5    0.297    16
#      3   18    18    -97.4    0.263    17
#      4   18    21    -81.7    0.325     3
#      5   18    23    -40.4    0.367     0
#      6   18    21     54.1    0.353     0
#      7   18    19    -99.1    0.291    15
#      8   17     6    -17.5    0.411     1
#      9   15    29    -11.4    0.448     0
#     10   14    25    -91.9    0.374    12
# Total extinctions: 0
# Generation time: 20.216 sec (15.728 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -98.34959 stdev: 28.65042
# Best fitness: 19.20793 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.315
# Mean genetic distance 2.807, standard deviation 0.581
# Population of 221 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    18    -99.6    0.261    15
#      2   19     2    -10.0    0.405     0
#      3   19    51    -66.1    0.225     0
#      4   19    20    -95.6    0.258     4
#      5   19    22    -41.1    0.292     1
#      6   19    20     19.2    0.294     1
#      7   19    18    -98.4    0.260    16
#      8   18    13    -98.6    0.304     2
#      9   16    31     -2.7    0.484     0
#     10   15    26    -91.8    0.371    13
# Total extinctions: 0
# Generation time: 21.117 sec (16.456 average)
#
#  ****** Running generation 20 ******
# Population's average fitness: -96.16392 stdev: 34.03034
# Best fitness: 70.25495 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.330
# Mean genetic distance 2.837, standard deviation 0.588
# Population of 220 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    17    -99.6    0.268    16
#      2   20     3    -94.1    0.339     1
#      3   20    46    -16.7    0.355     0
#      4   20    19    -77.5    0.276     5
#      5   20    23    -41.3    0.340     2
#      6   20    21     70.3    0.315     0
#      7   20    19    -98.8    0.307    17
#      8   19    16    -98.7    0.294     3
#      9   17    32     -1.6    0.473     0
#     10   16    24    -91.8    0.334    14
# Total extinctions: 0
# Generation time: 21.934 sec (16.922 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -94.71140 stdev: 28.85643
# Best fitness: 55.02903 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.338
# Mean genetic distance 2.811, standard deviation 0.595
# Population of 219 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    18    -99.1    0.303    17
#      2   21     6    -93.7    0.343     2
#      3   21    39    -16.5    0.377     0
#      4   21    18    -84.8    0.280     6
#      5   21    22    -21.1    0.344     0
#      6   21    22     55.0    0.339     1
#      7   21    20    -97.9    0.294    18
#      8   20    21    -98.7    0.303     4
#      9   18    30      1.2    0.436     0
#     10   17    23    -39.4    0.360     0
# Total extinctions: 0
# Generation time: 20.720 sec (17.678 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -94.21320 stdev: 27.68800
# Best fitness: 47.52905 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.273
# Mean genetic distance 2.797, standard deviation 0.576
# Population of 222 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    19    -97.4    0.239     0
#      2   22     7    -94.2    0.219     3
#      3   22    52     -7.9    0.323     0
#      4   22    19    -86.1    0.234     7
#      5   22    23    -43.8    0.292     1
#      6   22    21     47.5    0.258     2
#      7   22    19    -98.2    0.221    19
#      8   21     6    -93.9    0.239     5
#      9   19    31      1.7    0.374     0
#     10   18    25    -39.6    0.332     1
# Total extinctions: 0
# Generation time: 20.037 sec (18.395 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -95.11416 stdev: 29.93151
# Best fitness: 60.21422 - size: (6, 40) - species 6 - id 3766
#
# Species 7 with 19 members is stagnated: removing it
# Average adjusted fitness: 0.301
# Mean genetic distance 2.866, standard deviation 0.608
# Population of 221 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    10    -98.0    0.267     1
#      2   23     2    -93.8    0.287     4
#      3   23    71     -6.6    0.324     0
#      4   23    21    -80.9    0.237     8
#      5   23    25    -23.8    0.291     2
#      6   23    23     60.2    0.290     3
#      8   22     9    -94.0    0.279     6
#      9   20    31     -2.3    0.352     1
#     10   19    29    -36.6    0.384     0
# Total extinctions: 0
# Generation time: 22.404 sec (19.079 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -92.32316 stdev: 30.48204
# Best fitness: -3.98414 - size: (9, 37) - species 9 - id 4595
# Average adjusted fitness: 0.494
# Mean genetic distance 2.836, standard deviation 0.690
# Population of 219 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    15    -98.5    0.446     2
#      2   24     8   -103.2    0.453     5
#      3   24    48    -17.6    0.498     1
#      4   24    20    -77.2    0.409     9
#      5   24    24    -26.8    0.485     3
#      6   24    22     -9.0    0.458     4
#      8   23    20    -98.0    0.428     7
#      9   21    32     -4.0    0.660     2
#     10   20    30    -39.0    0.608     1
# Total extinctions: 0
# Generation time: 26.026 sec (20.536 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -91.66531 stdev: 32.15421
# Best fitness: 54.04596 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.345
# Mean genetic distance 2.794, standard deviation 0.683
# Population of 219 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    18    -76.5    0.291     0
#      2   25    33   -100.0    0.313     6
#      3   25    37    -18.4    0.357     2
#      4   25    19    -49.9    0.279     0
#      5   25    23    -26.5    0.320     4
#      6   25    23     54.0    0.333     5
#      8   24     3    -97.8    0.305     8
#      9   22    31     -2.4    0.441     3
#     10   21    32    -33.0    0.469     0
# Total extinctions: 0
# Generation time: 25.893 sec (21.689 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -92.06881 stdev: 33.44489
# Best fitness: 0.51790 - size: (9, 36) - species 9 - id 5390
# Average adjusted fitness: 0.428
# Mean genetic distance 2.825, standard deviation 0.705
# Population of 220 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    16    -76.3    0.335     0
#      2   26    12    -98.2    0.379     7
#      3   26    31     -3.0    0.447     0
#      4   26    18    -94.3    0.319     1
#      5   26    22    -27.0    0.372     5
#      6   26    24    -10.6    0.403     6
#      8   25    31    -99.5    0.396     9
#      9   23    32      0.5    0.559     4
#     10   22    34    -33.0    0.637     0
# Total extinctions: 0
# Generation time: 27.216 sec (22.471 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -97.15493 stdev: 32.46622
# Best fitness: 20.43371 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.396
# Mean genetic distance 2.813, standard deviation 0.697
# Population of 220 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    19    -75.5    0.350     0
#      2   27    31    -95.6    0.369     8
#      3   27    28     -3.1    0.417     1
#      4   27    19    -86.1    0.305     2
#      5   27    23    -21.0    0.403     0
#      6   27    23     20.4    0.363     7
#      8   26    13    -88.2    0.363    10
#      9   24    31      3.6    0.482     0
#     10   23    33     -4.2    0.512     0
# Total extinctions: 0
# Generation time: 24.280 sec (22.984 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -93.67347 stdev: 30.75336
# Best fitness: 60.92697 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.213
# Mean genetic distance 2.831, standard deviation 0.683
# Population of 217 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    21    -75.6    0.152     1
#      2   28    22    -95.6    0.177     9
#      3   28    27     -4.4    0.244     2
#      4   28    18    -84.0    0.166     3
#      5   28    25    -16.6    0.235     0
#      6   28    21     60.9    0.172     8
#      8   27    18    -88.0    0.182    11
#      9   25    30      0.4    0.266     1
#     10   24    35      2.5    0.325     0
# Total extinctions: 0
# Generation time: 23.484 sec (23.311 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -93.82069 stdev: 30.88208
# Best fitness: 68.40371 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.219
# Mean genetic distance 2.854, standard deviation 0.664
# Population of 218 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    30    -77.0    0.170     2
#      2   29    15    -95.6    0.176    10
#      3   29    28     -3.5    0.265     3
#      4   29    19    -71.1    0.162     4
#      5   29    24    -22.6    0.212     1
#      6   29    22     68.4    0.211     9
#      8   28    15    -83.6    0.178    12
#      9   26    31      0.8    0.284     2
#     10   25    34     -6.9    0.311     1
# Total extinctions: 0
# Generation time: 22.321 sec (23.431 average)
#
#  ****** Running generation 30 ******
# Population's average fitness: -93.87245 stdev: 33.95543
# Best fitness: 0.43422 - size: (8, 46) - species 3 - id 5376
# Average adjusted fitness: 0.436
# Mean genetic distance 2.829, standard deviation 0.627
# Population of 219 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    29    -77.4    0.385     3
#      2   30    16    -97.7    0.373    11
#      3   30    29      0.4    0.527     0
#      4   30    18    -94.3    0.328     5
#      5   30    25    -19.6    0.432     2
#      6   30    21    -17.1    0.365    10
#      8   29    18    -85.7    0.397    13
#      9   27    30      0.3    0.539     3
#     10   26    33     -6.9    0.580     2
# Total extinctions: 0
# Generation time: 28.677 sec (24.106 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -93.86403 stdev: 33.77925
# Best fitness: 64.77448 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.340
# Mean genetic distance 2.803, standard deviation 0.597
# Population of 220 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    23    -53.1    0.295     0
#      2   31    18    -97.9    0.293    12
#      3   31    28     -5.7    0.364     1
#      4   31    19    -93.3    0.289     6
#      5   31    24    -11.4    0.329     0
#      6   31    23     64.8    0.341    11
#      8   30    24    -88.6    0.322    14
#      9   28    29      1.2    0.386     4
#     10   27    32     -7.9    0.444     3
# Total extinctions: 0
# Generation time: 27.751 sec (24.809 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: -93.97990 stdev: 36.14848
# Best fitness: 60.76601 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.337
# Mean genetic distance 2.822, standard deviation 0.595
# Population of 221 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32    16    -76.9    0.267     1
#      2   32    21    -97.8    0.297    13
#      3   32    21    -13.7    0.379     2
#      4   32    18    -94.8    0.231     7
#      5   32    25    -23.6    0.349     1
#      6   32    24     60.8    0.330    12
#      8   31    27    -95.3    0.306    15
#      9   29    30      4.0    0.414     0
#     10   28    33     -6.2    0.458     4
#     11    0     6       --       --     0
# Total extinctions: 0
# Generation time: 29.902 sec (25.795 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -94.34093 stdev: 33.72274
# Best fitness: 19.27097 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.422
# Mean genetic distance 2.843, standard deviation 0.589
# Population of 220 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33    36    -75.4    0.339     2
#      2   33     2    -96.6    0.364    14
#      3   33    25    -40.6    0.464     3
#      4   33    17    -94.9    0.323     8
#      5   33    24    -23.3    0.447     2
#      6   33    22     19.3    0.394    13
#      8   32    21    -80.3    0.344    16
#      9   30    28      5.7    0.490     0
#     10   29    30     -2.5    0.529     5
#     11    1    15    -12.8    0.529     0
# Total extinctions: 0
# Generation time: 29.568 sec (26.512 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -90.77221 stdev: 36.62252
# Best fitness: 69.11992 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.353
# Mean genetic distance 2.874, standard deviation 0.604
# Population of 221 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34    22    -75.2    0.295     3
#      2   34    14    -98.5    0.270    15
#      3   34    17    -12.8    0.367     4
#      4   34    18    -92.1    0.281     9
#      5   34    23    -20.1    0.345     3
#      6   34    21     69.1    0.325    14
#      8   33    20    -96.6    0.325    17
#      9   31    29      4.2    0.464     1
#     10   30    31     -1.9    0.491     6
#     11    2    26      6.2    0.367     0
# Total extinctions: 0
# Generation time: 30.347 sec (26.944 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -95.23858 stdev: 35.20004
# Best fitness: 5.99216 - size: (9, 36) - species 9 - id 7193
# Average adjusted fitness: 0.473
# Mean genetic distance 2.866, standard deviation 0.613
# Population of 220 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35    23    -71.9    0.422     4
#      2   35     8    -96.3    0.431    16
#      3   35    21    -36.9    0.528     5
#      4   35    17    -93.9    0.351    10
#      5   35    22    -22.4    0.484     4
#      6   35    20    -19.3    0.411    15
#      8   34    26    -96.7    0.416    18
#      9   32    27      6.0    0.545     0
#     10   31    29     -1.7    0.570     7
#     11    3    27      5.5    0.569     1
# Total extinctions: 0
# Generation time: 29.405 sec (27.295 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: -82.65201 stdev: 37.53127
# Best fitness: 42.52625 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.279
# Mean genetic distance 2.846, standard deviation 0.621
# Population of 220 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36    17    -64.9    0.177     5
#      2   36    16    -98.6    0.160    17
#      3   36    22    -36.7    0.289     6
#      4   36    14    -93.7    0.151    11
#      5   36    23    -17.0    0.307     5
#      6   36    21     42.5    0.260    16
#      8   35    16    -83.2    0.204    19
#      9   33    26      5.9    0.315     1
#     10   32    35      0.5    0.519     8
#     11    4    30      5.6    0.411     2
# Total extinctions: 0
# Generation time: 31.598 sec (27.733 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -89.34686 stdev: 38.02161
# Best fitness: 66.83982 - size: (6, 40) - species 6 - id 3766
#
# Species 8 with 16 members is stagnated: removing it
# Average adjusted fitness: 0.328
# Mean genetic distance 2.849, standard deviation 0.618
# Population of 222 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37    18    -71.5    0.231     6
#      2   37    20    -82.7    0.267    18
#      3   37    28    -25.0    0.442     7
#      4   37    16    -92.9    0.229    12
#      5   37    23    -13.5    0.282     6
#      6   37    24     66.8    0.328    17
#      9   34    29      5.2    0.398     2
#     10   33    32      0.4    0.372     9
#     11    5    32      5.7    0.407     3
# Total extinctions: 0
# Generation time: 32.156 sec (28.521 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -90.75401 stdev: 36.32772
# Best fitness: 73.97198 - size: (7, 40) - species 6 - id 7841
# Average adjusted fitness: 0.329
# Mean genetic distance 2.838, standard deviation 0.603
# Population of 219 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38    17    -75.8    0.279     7
#      2   38    23    -86.2    0.272    19
#      3   38    31    -20.2    0.424     8
#      4   38    17    -93.6    0.251    13
#      5   38    22    -15.2    0.303     7
#      6   38    23     74.0    0.316     0
#      9   35    28      5.2    0.378     3
#     10   34    30      2.2    0.385    10
#     11    6    28      3.7    0.354     4
# Total extinctions: 0
# Generation time: 30.946 sec (29.267 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -88.92190 stdev: 39.93723
# Best fitness: 53.27031 - size: (6, 40) - species 6 - id 3766
#
# Species 2 with 23 members is stagnated: removing it
# Average adjusted fitness: 0.545
# Mean genetic distance 2.858, standard deviation 0.643
# Population of 220 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39    22    -84.2    0.496     8
#      3   39    33    -35.7    0.568     9
#      4   39    21    -94.7    0.461    14
#      5   39    25    -14.7    0.532     8
#      6   39    25     53.3    0.507     1
#      9   36    31      5.5    0.585     4
#     10   35    33      1.8    0.608    11
#     11    7    30      6.1    0.599     5
# Total extinctions: 0
# Generation time: 32.293 sec (30.265 average)
#
#  ****** Running generation 40 ******
# Population's average fitness: -86.47324 stdev: 37.28739
# Best fitness: 16.31889 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.418
# Mean genetic distance 2.854, standard deviation 0.627
# Population of 219 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40    23    -35.7    0.341     0
#      3   40    28     -2.2    0.500    10
#      4   40    20    -93.1    0.296    15
#      5   40    24    -14.1    0.371     9
#      6   40    24     16.3    0.358     2
#      9   37    32      5.1    0.514     5
#     10   36    31      1.5    0.434    12
#     11    8    37      5.8    0.534     6
# Total extinctions: 0
# Generation time: 33.050 sec (30.702 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -88.86731 stdev: 37.61431
# Best fitness: 6.00293 - size: (9, 46) - species 11 - id 8420
# Average adjusted fitness: 0.479
# Mean genetic distance 2.819, standard deviation 0.621
# Population of 219 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41    22    -47.1    0.399     1
#      3   41    23    -11.6    0.531    11
#      4   41    21    -92.6    0.356    16
#      5   41    26    -14.6    0.489    10
#      6   41    23     -0.7    0.407     3
#      9   38    31      4.8    0.514     6
#     10   37    32      2.1    0.566    13
#     11    9    41      6.0    0.569     7
# Total extinctions: 0
# Generation time: 32.071 sec (31.134 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: -88.88323 stdev: 37.33706
# Best fitness: 8.56667 - size: (9, 46) - species 11 - id 8420
# Average adjusted fitness: 0.462
# Mean genetic distance 2.791, standard deviation 0.600
# Population of 221 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42    23    -46.7    0.372     2
#      3   42    23     -9.2    0.465    12
#      4   42    22    -94.7    0.355    17
#      5   42    27    -14.4    0.466    11
#      6   42    22    -51.6    0.350     4
#      9   39    32      4.5    0.548     7
#     10   38    34      0.4    0.618    14
#     11   10    38      8.6    0.520     0
# Total extinctions: 0
# Generation time: 32.823 sec (31.426 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: -86.08193 stdev: 37.61391
# Best fitness: 32.46873 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.390
# Mean genetic distance 2.743, standard deviation 0.587
# Population of 220 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43    24    -45.5    0.356     3
#      3   43    28    -34.2    0.402    13
#      4   43    21    -94.4    0.293    18
#      5   43    25    -14.9    0.337    12
#      6   43    23     32.5    0.314     5
#      9   40    33      4.7    0.488     8
#     10   39    33      2.3    0.471    15
#     11   11    33      8.3    0.455     1
# Total extinctions: 0
# Generation time: 33.999 sec (31.869 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: -85.62782 stdev: 38.97905
# Best fitness: 84.52926 - size: (6, 40) - species 6 - id 3766
# Average adjusted fitness: 0.349
# Mean genetic distance 2.711, standard deviation 0.591
# Population of 218 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44    22    -48.1    0.296     4
#      3   44    28    -37.5    0.381    14
#      4   44    20    -93.6    0.256    19
#      5   44    26    -14.6    0.333    13
#      6   44    24     84.5    0.317     0
#      9   41    32      5.7    0.417     9
#     10   40    32      2.4    0.401    16
#     11   12    34      8.0    0.388     2
# Total extinctions: 0
# Generation time: 34.226 sec (32.257 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: -85.92313 stdev: 39.90485
# Best fitness: 84.72849 - size: (6, 32) - species 6 - id 9271
#
# Species 4 with 20 members is stagnated: removing it
# Average adjusted fitness: 0.339
# Mean genetic distance 2.687, standard deviation 0.620
# Population of 221 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45    25    -43.9    0.291     5
#      3   45    33    -40.2    0.334    15
#      5   45    29    -14.0    0.293    14
#      6   45    28     84.7    0.312     0
#      9   42    35      5.5    0.351    10
#     10   41    38      0.6    0.431    17
#     11   13    33      9.5    0.364     0
# Total extinctions: 0
# Generation time: 33.987 sec (32.715 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: -85.16093 stdev: 40.09787
# Best fitness: 122.11541 - size: (6, 39) - species 6 - id 9475
# Average adjusted fitness: 0.211
# Mean genetic distance 2.710, standard deviation 0.613
# Population of 221 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46    26    -39.6    0.177     6
#      3   46    32    -21.1    0.212    16
#      5   46    28    -15.2    0.175    15
#      6   46    30    122.1    0.218     0
#      9   43    34      5.4    0.222    11
#     10   42    37    -12.3    0.243    18
#     11   14    34      7.7    0.229     1
# Total extinctions: 0
# Generation time: 32.239 sec (32.779 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: -77.05349 stdev: 46.40590
# Best fitness: 161.16255 - size: (6, 30) - species 6 - id 9676
#
# Best individual in generation 47 meets fitness threshold - complexity: (6, 30)
# Key: 9676
# Fitness: 161.16255023429648
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.24865624817489052, response=1.0, activation=tanh, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.8074037846047188, response=1.0, activation=tanh, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=-3.6966975223123733, response=1.0, activation=tanh, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=0.48333699065796537, response=1.0, activation=tanh, aggregation=sum)
# 	379 DefaultNodeGene(key=379, bias=-0.6938673441484452, response=1.0, activation=tanh, aggregation=sum)
# 	1151 DefaultNodeGene(key=1151, bias=-1.2486798351718127, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-14, 2), weight=0.21183372161306427, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=0.7131779603695756, enabled=True)
# 	DefaultConnectionGene(key=(-14, 379), weight=-0.28958592690855584, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=0.04364273166456356, enabled=True)
# 	DefaultConnectionGene(key=(-13, 1), weight=-0.9993545851925083, enabled=False)
# 	DefaultConnectionGene(key=(-13, 2), weight=-1.6031233190645549, enabled=True)
# 	DefaultConnectionGene(key=(-13, 3), weight=1.4951448209970557, enabled=True)
# 	DefaultConnectionGene(key=(-13, 379), weight=-0.03104701901217417, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-1.5389292896451823, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1), weight=-0.12313994048836827, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=-1.1576118658058965, enabled=True)
# 	DefaultConnectionGene(key=(-12, 379), weight=2.7629071389806237, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=-1.8453988042605307, enabled=True)
# 	DefaultConnectionGene(key=(-11, 1), weight=-0.35377963467386286, enabled=True)
# 	DefaultConnectionGene(key=(-11, 379), weight=0.4214800032776839, enabled=False)
# 	DefaultConnectionGene(key=(-10, 1), weight=1.654735020776429, enabled=True)
# 	DefaultConnectionGene(key=(-10, 3), weight=0.2690020689956548, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=-1.8346718802852284, enabled=True)
# 	DefaultConnectionGene(key=(-9, 3), weight=-0.035122220327053415, enabled=False)
# 	DefaultConnectionGene(key=(-9, 379), weight=0.8829999812769475, enabled=False)
# 	DefaultConnectionGene(key=(-8, 0), weight=-1.9369313339434648, enabled=True)
# 	DefaultConnectionGene(key=(-8, 379), weight=-0.5078579721811072, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.13691318852925471, enabled=False)
# 	DefaultConnectionGene(key=(-7, 1), weight=-3.4586881625294366, enabled=True)
# 	DefaultConnectionGene(key=(-7, 2), weight=0.6706348424517224, enabled=False)
# 	DefaultConnectionGene(key=(-6, 1), weight=-1.0775038007491053, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-0.9515264811042481, enabled=True)
# 	DefaultConnectionGene(key=(-5, 379), weight=-0.8714457590494831, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-1.6120727349179258, enabled=False)
# 	DefaultConnectionGene(key=(-3, 379), weight=-1.3474128954532116, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=-1.5345669188137439, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=-0.9441352389396098, enabled=False)
# 	DefaultConnectionGene(key=(-2, 3), weight=-2.6832004896116652, enabled=True)
# 	DefaultConnectionGene(key=(-2, 379), weight=1.1246313458285533, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=3.2773015253624775, enabled=True)
# 	DefaultConnectionGene(key=(-1, 2), weight=-1.095893860100109, enabled=True)
# 	DefaultConnectionGene(key=(-1, 3), weight=1.822047772313657, enabled=False)
# 	DefaultConnectionGene(key=(379, 2), weight=-0.8087377383194652, enabled=True)
# 	DefaultConnectionGene(key=(379, 3), weight=-0.7176700379472349, enabled=False)
# 	DefaultConnectionGene(key=(1151, 1), weight=1.0699757150763594, enabled=True)

# %%
##TEST####
import os
import pickle
import neat
import gym
import numpy as np
from gym.wrappers import Monitor

with open('winner-feedforward nn', 'rb') as f:
    c = pickle.load(f)
    
print('Loaded genome:')
print(c)

# Load the config file, which is assumed to live in
# the same directory as this script.
local_dir = os.path.dirname("__file__")
config_path = os.path.join(local_dir, 'config-feedforward nn')
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     config_path)

net = neat.nn.FeedForwardNetwork.create(c, config)
# net = neat.nn.recurrent.RecurrentNetwork.create(c, config)

env = Monitor(gym.make("BipedalWalker-v3"), 'inference', force = True)  #saves the video 
observation = env.reset()[0:14]

done = False
while not done:
    action = net.activate(observation)
    
    observation, reward, done, info = env.step(action)
    observation = observation[0:14]
    env.render()
    
env.close()
# Out:
# Loaded genome:
# Key: 9676
# Fitness: 161.16255023429648
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.24865624817489052, response=1.0, activation=tanh, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.8074037846047188, response=1.0, activation=tanh, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=-3.6966975223123733, response=1.0, activation=tanh, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=0.48333699065796537, response=1.0, activation=tanh, aggregation=sum)
# 	379 DefaultNodeGene(key=379, bias=-0.6938673441484452, response=1.0, activation=tanh, aggregation=sum)
# 	1151 DefaultNodeGene(key=1151, bias=-1.2486798351718127, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-14, 2), weight=0.21183372161306427, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=0.7131779603695756, enabled=True)
# 	DefaultConnectionGene(key=(-14, 379), weight=-0.28958592690855584, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=0.04364273166456356, enabled=True)
# 	DefaultConnectionGene(key=(-13, 1), weight=-0.9993545851925083, enabled=False)
# 	DefaultConnectionGene(key=(-13, 2), weight=-1.6031233190645549, enabled=True)
# 	DefaultConnectionGene(key=(-13, 3), weight=1.4951448209970557, enabled=True)
# 	DefaultConnectionGene(key=(-13, 379), weight=-0.03104701901217417, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-1.5389292896451823, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1), weight=-0.12313994048836827, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=-1.1576118658058965, enabled=True)
# 	DefaultConnectionGene(key=(-12, 379), weight=2.7629071389806237, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=-1.8453988042605307, enabled=True)
# 	DefaultConnectionGene(key=(-11, 1), weight=-0.35377963467386286, enabled=True)
# 	DefaultConnectionGene(key=(-11, 379), weight=0.4214800032776839, enabled=False)
# 	DefaultConnectionGene(key=(-10, 1), weight=1.654735020776429, enabled=True)
# 	DefaultConnectionGene(key=(-10, 3), weight=0.2690020689956548, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=-1.8346718802852284, enabled=True)
# 	DefaultConnectionGene(key=(-9, 3), weight=-0.035122220327053415, enabled=False)
# 	DefaultConnectionGene(key=(-9, 379), weight=0.8829999812769475, enabled=False)
# 	DefaultConnectionGene(key=(-8, 0), weight=-1.9369313339434648, enabled=True)
# 	DefaultConnectionGene(key=(-8, 379), weight=-0.5078579721811072, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.13691318852925471, enabled=False)
# 	DefaultConnectionGene(key=(-7, 1), weight=-3.4586881625294366, enabled=True)
# 	DefaultConnectionGene(key=(-7, 2), weight=0.6706348424517224, enabled=False)
# 	DefaultConnectionGene(key=(-6, 1), weight=-1.0775038007491053, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-0.9515264811042481, enabled=True)
# 	DefaultConnectionGene(key=(-5, 379), weight=-0.8714457590494831, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-1.6120727349179258, enabled=False)
# 	DefaultConnectionGene(key=(-3, 379), weight=-1.3474128954532116, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=-1.5345669188137439, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=-0.9441352389396098, enabled=False)
# 	DefaultConnectionGene(key=(-2, 3), weight=-2.6832004896116652, enabled=True)
# 	DefaultConnectionGene(key=(-2, 379), weight=1.1246313458285533, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=3.2773015253624775, enabled=True)
# 	DefaultConnectionGene(key=(-1, 2), weight=-1.095893860100109, enabled=True)
# 	DefaultConnectionGene(key=(-1, 3), weight=1.822047772313657, enabled=False)
# 	DefaultConnectionGene(key=(379, 2), weight=-0.8087377383194652, enabled=True)
# 	DefaultConnectionGene(key=(379, 3), weight=-0.7176700379472349, enabled=False)
# 	DefaultConnectionGene(key=(1151, 1), weight=1.0699757150763594, enabled=True)
# /home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
os.getcwd()
